# %% [markdown]
# # Dépendances

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mt
import matplotlib.pyplot as plt

# %% [markdown]
# # Exercice 1

# %%
data = pd.read_csv('./data/house_pricing.csv')

# %%
#1.2
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
#1.3
sns.relplot(x='SalePrice' ,y='LotArea', data=data)

# %%
#1.4
condition = data[ ( data['LotArea'] < 20000 ) & ( data['SalePrice'] < 500000 ) ]
sns.relplot(x='SalePrice' ,y='LotArea', data=condition)

# %%
#1.5
sns.relplot(x='LotFrontage', y='LotArea', data=data)

# %%
#1.5
condition2 = data[ (data['LotFrontage'] < 200) & (data['LotArea'] < 100000) ]
sns.relplot(x='LotFrontage', y='LotArea', data=condition2)

# %% [markdown]
# # Exercice 2

# %% [markdown]
# 2.2 - En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution
# des prix par rapport au temps. Que pouvez vous voir ?

# %%
data2 = pd.read_csv('./data/sales_predictions.csv', nrows=500)

# %%
sns.relplot(x='date',y='item_price', data=data2)

# %% [markdown]
# 2.3 - Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas,
# prenez un échantillons de 50 éléments dans votre dataset
# Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
sample = data2.sample(50)
sns.relplot(x='date',y='item_price', data=sample)

# %% [markdown]
# 2.4 - Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ?

# %%
sns.relplot(x='date',y='item_price', data=sample, sizes=(20,6))

# %% [markdown]
# 2.5/2.6 - En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime
# Retentez une dernière fois votre visualisation.

# %%
sample['date'] = pd.to_datetime(sample['date'])
sns.relplot(x='date',y='item_price', data=sample, sizes=(20,6))
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Exercice 3

# %%
data3 = pd.read_csv('./data/IBM_HR_ATTRITION.csv')

# %% [markdown]
# 2) En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution
# des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction

# %%
sns.catplot(x='Attrition',y='JobSatisfaction', data=data3)

# %% [markdown]
# 3) Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?

# %%
sns.catplot(x='Attrition',y='JobSatisfaction', data=data3, kind="box")

# %% [raw]
# S = série statistique \ S = {x}^n
# µ = mu =  moyenne (Moyenne = 1 sur n  de x = x1 + x2 + ... xn
# V = 1/n Différence (xi et µ)²
# V = Variance
# & = racine carré de V
# S = {1, 100}
